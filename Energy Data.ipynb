# %%
import pandas as pd
import matplotlib.pyplot as plt
df =pd.read_excel("C:/Users/YBUCK MAX/Desktop/Python Project/Energy Data/Energy Data.xlsx")
df
# Out:
#     Year  Energy Related CO2missions (Gigatonnes)  \
# 0   1991                                     20.6
# 1   1992                                     20.5
# 2   1993                                     20.6
# 3   1994                                     20.7
# 4   1995                                     21.3
# 5   1996                                     21.7
# 6   1997                                     22.1
# 7   1998                                     22.3
# 8   1999                                     22.4
# 9   2000                                     23.1
# 10  2001                                     23.5
# 11  2002                                     23.8
# 12  2003                                     24.9
# 13  2004                                     26.0
# 14  2005                                     27.0
# 15  2006                                     27.8
# 16  2007                                     28.9
# 17  2008                                     29.1
# 18  2009                                     28.7
# 19  2010                                     30.4
# 20  2011                                     31.3
# 21  2012                                     31.6
# 22  2013                                     32.2
# 23  2014                                     32.3
# 24  2015                                     32.2
# 25  2016                                     32.2
# 26  2017                                     32.7
# 27  2018                                     33.5
# 28  2019                                     33.4
# 29  2020                                     31.5
# 30  2021                                     33.0
# 31  2022                                      NaN
#
#     Oil Production (Million barrels per day)  \
# 0                                      65.44
# 1                                      65.71
# 2                                      65.99
# 3                                      66.89
# 4                                      67.85
# 5                                      69.67
# 6                                      71.85
# 7                                      73.28
# 8                                      71.83
# 9                                      74.48
# 10                                     74.49
# 11                                     74.95
# 12                                     77.57
# 13                                     80.97
# 14                                     82.01
# 15                                     82.48
# 16                                     82.29
# 17                                     82.93
# 18                                     81.26
# 19                                     83.29
# 20                                     84.04
# 21                                     86.26
# 22                                     86.67
# 23                                     88.83
# 24                                     91.63
# 25                                     91.99
# 26                                     92.57
# 27                                     94.85
# 28                                     94.96
# 29                                     88.39
# 30                                     89.90
# 31                                       NaN
#
#     Natural Gas Production (Billion Cubic Metres)  \
# 0                                          2026.8
# 1                                          2039.4
# 2                                          2073.5
# 3                                          2095.7
# 4                                          2136.1
# 5                                          2230.0
# 6                                          2233.0
# 7                                          2284.1
# 8                                          2339.3
# 9                                          2421.8
# 10                                         2477.2
# 11                                         2518.9
# 12                                         2616.6
# 13                                         2688.5
# 14                                         2770.4
# 15                                         2869.4
# 16                                         2939.3
# 17                                         3047.2
# 18                                         2955.9
# 19                                         3150.8
# 20                                         3258.0
# 21                                         3326.8
# 22                                         3366.1
# 23                                         3437.9
# 24                                         3511.7
# 25                                         3552.1
# 26                                         3676.2
# 27                                         3852.9
# 28                                         3976.2
# 29                                         3853.7
# 30                                            NaN
# 31                                            NaN
#
#     Coal Production (million tons)  Electricity Generation (Terawatt-hours)  \
# 0                           4481.0                                  12218.0
# 1                           4432.0                                  12330.0
# 2                           4327.0                                  12592.0
# 3                           4402.0                                  12917.0
# 4                           4557.0                                  13375.0
# 5                           4622.0                                  13789.0
# 6                           4621.0                                  14121.0
# 7                           4569.0                                  14503.0
# 8                           4499.0                                  14918.0
# 9                           4638.0                                  15556.0
# 10                          4860.0                                  15789.0
# 11                          4914.0                                  16345.0
# 12                          5263.0                                  16924.0
# 13                          5663.0                                  17727.0
# 14                          6022.0                                  18454.0
# 15                          6367.0                                  19155.0
# 16                          6644.0                                  20046.0
# 17                          6842.0                                  20422.0
# 18                          6968.0                                  20265.0
# 19                          7354.0                                  21570.7
# 20                          7833.0                                  22257.0
# 21                          7936.0                                  22806.3
# 22                          7976.0                                  23435.2
# 23                          7939.0                                  24031.7
# 24                          7669.0                                  24270.5
# 25                          7293.0                                  24915.2
# 26                          7545.0                                  25623.9
# 27                          7827.0                                  26659.1
# 28                          7960.0                                  27001.0
# 29                          7575.0                                  26889.0
# 30                             NaN                                  28466.0
# 31                             NaN                                      NaN
#
#     Hydroelectricity consumption in TWh  Nuclear energy consumption in TWh  \
# 0                               2247.96                            2089.56
# 1                               2240.48                            2105.40
# 2                               2364.56                            2179.32
# 3                               2382.16                            2217.60
# 4                               2508.44                            2314.84
# 5                               2548.92                            2397.12
# 6                               2589.40                            2381.28
# 7                               2620.64                            2422.20
# 8                               2640.00                            2514.16
# 9                               2714.36                            2574.00
# 10                              2615.80                            2645.28
# 11                              2633.84                            2686.20
# 12                              2632.96                            2632.52
# 13                              2797.52                            2749.56
# 14                              2914.12                            2757.48
# 15                              3023.68                            2794.88
# 16                              3081.76                            2735.92
# 17                              3201.88                            2723.60
# 18                              3245.00                            2702.04
# 19                              3427.16                            2755.72
# 20                              3482.60                            2636.92
# 21                              3655.08                            2461.80
# 22                              3781.36                            2480.72
# 23                              3870.68                            2530.00
# 24                              3874.20                            2564.32
# 25                              4018.52                            2601.28
# 26                              4041.84                            2624.16
# 27                              4231.00                            2700.46
# 28                              4294.00                            2796.35
# 29                              4370.00                            2693.98
# 30                              4250.00                            2800.27
# 31                                  NaN                                NaN
#
#     Installed Solar Capacity (GW)  Installed Wind Capacity in GW
# 0                             NaN                           1.93
# 1                             NaN                           2.17
# 2                             NaN                           2.50
# 3                             NaN                           2.99
# 4                             NaN                           3.49
# 5                             NaN                           6.10
# 6                             NaN                           7.60
# 7                             NaN                          10.20
# 8                             NaN                          13.60
# 9                             1.3                          17.00
# 10                            1.6                          24.00
# 11                            2.1                          31.00
# 12                            2.6                          39.00
# 13                            3.7                          48.00
# 14                            5.1                          59.00
# 15                            6.7                          74.00
# 16                            9.2                          94.00
# 17                           16.0                         121.00
# 18                           23.0                         159.00
# 19                           40.0                         198.00
# 20                           70.0                         238.00
# 21                          101.0                         283.00
# 22                          138.0                         319.00
# 23                          178.0                         370.00
# 24                          230.0                         433.00
# 25                          308.0                         488.00
# 26                          407.0                         540.00
# 27                          508.0                         592.00
# 28                          629.0                         651.00
# 29                          773.2                         744.00
# 30                          939.0                         837.00
# 31                            NaN                            NaN

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Year                                           32 non-null     int64
#  1   Energy Related CO2missions (Gigatonnes)        31 non-null     float64
#  2   Oil Production (Million barrels per day)       31 non-null     float64
#  3   Natural Gas Production (Billion Cubic Metres)  30 non-null     float64
#  4   Coal Production (million tons)                 30 non-null     float64
#  5   Electricity Generation (Terawatt-hours)        31 non-null     float64
#  6   Hydroelectricity consumption in TWh            31 non-null     float64
#  7   Nuclear energy consumption in TWh              31 non-null     float64
#  8   Installed Solar Capacity (GW)                  22 non-null     float64
#  9   Installed Wind Capacity in GW                  31 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 2.6 KB
# (32, 10)

# %%
df.isnull().sum()
# Out:
# Year                                              0
# Energy Related CO2missions (Gigatonnes)           1
# Oil Production (Million barrels per day)          1
# Natural Gas Production (Billion Cubic Metres)     2
# Coal Production (million tons)                    2
# Electricity Generation (Terawatt-hours)           1
# Hydroelectricity consumption in TWh               1
# Nuclear energy consumption in TWh                 1
# Installed Solar Capacity (GW)                    10
# Installed Wind Capacity in GW                     1
# dtype: int64

# %%
#df.dropna(inplace=True)
df['Installed Solar Capacity (GW)'] = df['Installed Solar Capacity (GW)'].fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Year                                           32 non-null     int64
#  1   Energy Related CO2missions (Gigatonnes)        31 non-null     float64
#  2   Oil Production (Million barrels per day)       31 non-null     float64
#  3   Natural Gas Production (Billion Cubic Metres)  30 non-null     float64
#  4   Coal Production (million tons)                 30 non-null     float64
#  5   Electricity Generation (Terawatt-hours)        31 non-null     float64
#  6   Hydroelectricity consumption in TWh            31 non-null     float64
#  7   Nuclear energy consumption in TWh              31 non-null     float64
#  8   Installed Solar Capacity (GW)                  32 non-null     float64
#  9   Installed Wind Capacity in GW                  31 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 2.6 KB

# %%
#CO2 emissions in the last three decades

plt.plot(df['Year'], df['Energy Related CO2missions (Gigatonnes)'],label='CO2 Emissions', linewidth=2, color='r')
plt.rcParams["figure.figsize"] = (8,16)
plt.xlabel('Year')
plt.ylabel('CO2 emissions in Gigatonnes')
plt.title('Emisssions trend in the last three decades')
plt.legend()
plt.grid()
plt.show()

# %%
#How have global emissions of carbon dioxide (CO2) from fossil fuels and land use changed over time?
#create a figure plot with Four subplots and the production of Oil, Natural gas and Coal Trend over the decade (All four on same plot not subplots perse)
plt.plot(df['Year'], df['Oil Production (Million barrels per day)'],label='Oil Production', linewidth=2)
plt.plot(df['Year'], df['Natural Gas Production (Billion Cubic Metres)'],label='Natural Gas Production', linewidth=2)
plt.plot(df['Year'], df['Coal Production (million tons)'],label='Coal Production', linewidth=2)
plt.rcParams["figure.figsize"] = (8,16)
plt.xlabel('Year')
plt.ylabel('CO2 emissions in Gigatonnes')
plt.title('Emisssions trend in the last three decades')
plt.legend()
plt.grid()
plt.show()

# %%
#create a figure plot with renewable energy production over the last 3 decades 
plt.plot(df['Year'], df['Installed Solar Capacity (GW)'],label='Installed Solar Capacity', linewidth=2)
plt.plot(df['Year'], df['Installed Wind Capacity in GW'],label='Installed Wind Capacity', linewidth=2)
plt.rcParams["figure.figsize"] = (6,10)
plt.xlabel('Year')
plt.ylabel('Renewable nergy generated in GW')
plt.title('Energy production trend in the last three decades')
plt.legend()
plt.grid()
plt.show()

# %%
#create a figure plot with Hydroelectricity  and nuclear energy consumption over the last 3 decades 

#plt.plot(df['Year'], df['Electricity Generation (Terawatt-hours)'],label='Hydroelectricity Generated', linewidth=2)
plt.plot(df['Year'], df['Hydroelectricity consumption in TWh'],label='Hydroelectricity Consumption', linewidth=2)
plt.plot(df['Year'], df['Nuclear energy consumption in TWh'],label='Nuclear energy Consumption', linewidth=2)

plt.rcParams["figure.figsize"] = (6,10)
plt.xlabel('Year')
plt.ylabel('CO2 emissions in Gigatonnes')
plt.title('Energy production trend in the last three decades')
plt.legend()
plt.grid()
plt.show()
